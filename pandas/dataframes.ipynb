# %%
import pandas as pd

dictionary = {"a" : [1, 2, 3], "b" : [2, 3, 4], "c" : [3, 5, 6]}

df = pd.DataFrame(dictionary, index=[1, 2, 3])

df
# Out:
#    a  b  c
# 1  1  2  3
# 2  2  3  5
# 3  3  4  6

# %%
data = [[1,2,3], [2,3,4], [3,4,5]]

df = pd.DataFrame(data, index=[1,2,3], columns=["a", "b", "c"])

df
# Out:
#    a  b  c
# 1  1  2  3
# 2  2  3  4
# 3  3  4  5

# %%
df = pd.read_csv("sample_data/california_housing_test.csv")
df.head(20)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 1     -118.30     34.26                43.0       1510.0           310.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 3     -118.36     33.82                28.0         67.0            15.0
# 4     -119.67     36.33                19.0       1241.0           244.0
# 5     -119.56     36.51                37.0       1018.0           213.0
# 6     -121.43     38.63                43.0       1009.0           225.0
# 7     -120.65     35.48                19.0       2310.0           471.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 9     -118.02     34.08                31.0       2402.0           632.0
# 10    -118.24     33.98                45.0        972.0           249.0
# 11    -119.12     35.85                37.0        736.0           166.0
# 12    -121.93     37.25                36.0       1089.0           182.0
# 13    -117.03     32.97                16.0       3936.0           694.0
# 14    -117.97     33.73                27.0       2097.0           325.0
# 15    -117.99     33.81                42.0        161.0            40.0
# 16    -120.81     37.53                15.0        570.0           123.0
# 17    -121.20     38.69                26.0       3077.0           607.0
# 18    -118.88     34.21                26.0       1590.0           196.0
# 19    -122.59     38.01                35.0       8814.0          1307.0
#
#     population  households  median_income  median_house_value
# 0       1537.0       606.0         6.6085            344700.0
# 1        809.0       277.0         3.5990            176500.0
# 2       1484.0       495.0         5.7934            270500.0
# 3         49.0        11.0         6.1359            330000.0
# 4        850.0       237.0         2.9375             81700.0
# 5        663.0       204.0         1.6635             67000.0
# 6        604.0       218.0         1.6641             67000.0
# 7       1341.0       441.0         3.2250            166900.0
# 8       1446.0       599.0         3.6696            194400.0
# 9       2830.0       603.0         2.3333            164200.0
# 10      1288.0       261.0         2.2054            125000.0
# 11       564.0       138.0         2.4167             58300.0
# 12       535.0       170.0         4.6900            252600.0
# 13      1935.0       659.0         4.5625            231200.0
# 14      1217.0       331.0         5.7121            222500.0
# 15       157.0        50.0         2.2000            153100.0
# 16       189.0       107.0         1.8750            181300.0
# 17      1603.0       595.0         2.7174            137500.0
# 18       654.0       199.0         6.5851            300000.0
# 19      3450.0      1258.0         6.1724            414300.0

# %%
# Get all entries where the population is greater than 1000
df_pop = df[df["population"] > 1000]
df_pop.head(20)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.05     37.37                27.0       3885.0           661.0
# 2     -117.81     33.78                27.0       3589.0           507.0
# 7     -120.65     35.48                19.0       2310.0           471.0
# 8     -122.84     38.40                15.0       3080.0           617.0
# 9     -118.02     34.08                31.0       2402.0           632.0
# 10    -118.24     33.98                45.0        972.0           249.0
# 13    -117.03     32.97                16.0       3936.0           694.0
# 14    -117.97     33.73                27.0       2097.0           325.0
# 17    -121.20     38.69                26.0       3077.0           607.0
# 19    -122.59     38.01                35.0       8814.0          1307.0
# 22    -118.16     34.07                47.0       2994.0           543.0
# 23    -122.20     37.79                45.0       2021.0           528.0
# 24    -117.28     33.28                13.0       6131.0          1040.0
# 26    -122.42     37.76                52.0       3587.0          1030.0
# 27    -118.39     33.99                32.0       2612.0           418.0
# 28    -118.45     34.07                19.0       4845.0          1609.0
# 29    -118.48     34.01                30.0       3078.0           954.0
# 31    -118.30     33.91                34.0       1617.0           493.0
# 32    -121.13     39.31                17.0       3442.0           705.0
# 33    -118.08     34.55                 5.0      16181.0          2971.0
#
#     population  households  median_income  median_house_value
# 0       1537.0       606.0         6.6085            344700.0
# 2       1484.0       495.0         5.7934            270500.0
# 7       1341.0       441.0         3.2250            166900.0
# 8       1446.0       599.0         3.6696            194400.0
# 9       2830.0       603.0         2.3333            164200.0
# 10      1288.0       261.0         2.2054            125000.0
# 13      1935.0       659.0         4.5625            231200.0
# 14      1217.0       331.0         5.7121            222500.0
# 17      1603.0       595.0         2.7174            137500.0
# 19      3450.0      1258.0         6.1724            414300.0
# 22      1651.0       561.0         3.8644            241500.0
# 23      1410.0       480.0         2.7788            115400.0
# 24      4049.0       940.0         3.8156            150700.0
# 26      2259.0       979.0         2.5403            250000.0
# 27      1030.0       402.0         6.6030            369200.0
# 28      3751.0      1539.0         1.5830            350000.0
# 29      1561.0       901.0         3.4852            425000.0
# 31      1530.0       500.0         2.6182            172600.0
# 32      1693.0       619.0         2.8102            128900.0
# 33      8152.0      2651.0         4.5237            141800.0

# %%
# Plot the population
df["population"].plot()
# Out:
# <Axes: >

# %%
# Plot the population and median income
df.plot(x="population", y="median_income", kind="scatter", title="Population vs Median Income", grid=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Plot the population and median income
# ----> 2 df.plot(x="population", y="median_income", kind="scatter", title="Population vs Median Income", grid=True, markersize=1)
#
# File ~/miniconda3/envs/basics/lib/python3.12/site-packages/pandas/plotting/_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     973 if kind in self._dataframe_kinds:
#     974     if isinstance(data, ABCDataFrame):
# --> 975         return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     976     else:
#     977         raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# File ~/miniconda3/envs/basics/lib/python3.12/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/miniconda3/envs/basics/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File ~/miniconda3/envs/basics/lib/python3.12/site-packages/pandas/plotting/_matplotlib/core.py:1345, in ScatterPlot._make_plot(self, fig)
#    1343 else:
#    1344     label = None
# -> 1345 scatter = ax.scatter(
#    1346     data[x].values,
#    1347     data[y].values,
#    1348     c=c_values,
#    1349     label=label,
#    1350     cmap=cmap,
#    1351     norm=norm,
#    1352     s=self.s,
#    1353     **self.kwds,
#    1354 )
#    1355 if cb:
#    1356     cbar_label = c if c_is_column else ""
#
# File ~/miniconda3/envs/basics/lib/python3.12/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/basics/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4766, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4762         keys_str = ", ".join(f"'{k}'" for k in extra_keys)
#    4763         _api.warn_external(
#    4764             "No data for colormapping provided via 'c'. "
#    4765             f"Parameters {keys_str} will be ignored")
# -> 4766 collection._internal_update(kwargs)
#    4768 # Classic mode only:
#    4769 # ensure there are margins to allow for the
#    4770 # finite size of the symbols.  In v2.x, margins
#    4771 # are present by default, so we disable this
#    4772 # scatter-specific override.
#    4773 if mpl.rcParams['_internal.classic_mode']:
#
# File ~/miniconda3/envs/basics/lib/python3.12/site-packages/matplotlib/artist.py:1219, in Artist._internal_update(self, kwargs)
#    1212 def _internal_update(self, kwargs):
#    1213     """
#    1214     Update artist properties without prenormalizing them, but generating
#    1215     errors as if calling `set`.
#    1216
#    1217     The lack of prenormalization is to maintain backcompatibility.
#    1218     """
# -> 1219     return self._update_props(
#    1220         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1221         "{prop_name!r}")
#
# File ~/miniconda3/envs/basics/lib/python3.12/site-packages/matplotlib/artist.py:1193, in Artist._update_props(self, props, errfmt)
#    1191             func = getattr(self, f"set_{k}", None)
#    1192             if not callable(func):
# -> 1193                 raise AttributeError(
#    1194                     errfmt.format(cls=type(self), prop_name=k))
#    1195             ret.append(func(v))
#    1196 if ret:
#
# AttributeError: PathCollection.set() got an unexpected keyword argument 'markersize'
